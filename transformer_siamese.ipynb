# %%
# !pip install tensorflow
# !pip install transformers tensorboard --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (2.11.0)
# Requirement already satisfied: packaging in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (0.30.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 6.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (23.1.21)
# Requirement already satisfied: wrapt>=1.11.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/halim/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Installing collected packages: tensorboard-data-server, tensorboard
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.0
#     Uninstalling tensorboard-2.12.0:
#       Successfully uninstalled tensorboard-2.12.0
# Successfully installed tensorboard-2.11.2 tensorboard-data-server-0.6.1
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (4.26.1)
# Requirement already satisfied: tensorboard in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (2.11.2)
# Collecting tensorboard
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 8.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (22.0)
# Requirement already satisfied: filelock in /home/halim/.local/lib/python3.10/site-packages (from transformers) (3.8.2)
# Requirement already satisfied: requests in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (0.11.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: setuptools>=41.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (65.6.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /home/halim/.local/lib/python3.10/site-packages (from tensorboard) (1.3.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (2.16.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: protobuf>=3.19.6 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (3.19.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (2.2.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 9.8 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: markdown>=2.6.8 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: wheel>=0.26 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (0.38.4)
# Requirement already satisfied: grpcio>=1.48.2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/halim/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/halim/.local/lib/python3.10/site-packages (from requests->transformers) (1.26.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.2)
# Installing collected packages: tensorboard-data-server, tensorboard
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.12.0 which is incompatible.
# tensorflow-cpu 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.12.0 which is incompatible.
# Successfully installed tensorboard-2.12.0 tensorboard-data-server-0.7.0

# %% [markdown]
# ### DigiFace-1M Dataset
#
# https://github.com/microsoft/DigiFace1M
#
# The DigiFace-1M dataset is a collection of over one million diverse synthetic face images for face recognition.
#
# It was introduced in our paper DigiFace-1M: 1 Million Digital Face Images for Face Recognition and can be used to train deep learning models for facial recognition.
#
# The dataset contains:
#
#     720K images with 10K identities (72 images per identity). For each identity, 4 different sets of accessories are sampled and 18 images are rendered for each set.
#     500K images with 100K identities (5 images per identity). For each identity, only one set of accessories is sampled.
#
# The DigiFace-1M dataset can be used for non-commercial research, and is licensed under the license found in LICENSE.

# %%
import os

home=os.path.abspath(os.getcwd())
data_path=os.path.join(home, 'data')

#global data
pairs=[]
classes=[]
IMAGE_DIMS = 224 # was 224 pixels

for file in os.listdir(data_path):
    classes.append(file)

# %%
print(len(classes))
# Out:
# 2000

# %%
import cv2

def preprocess(img, size=IMAGE_DIMS, interpolation =cv2.INTER_AREA):
    #extract image size
    h, w = img.shape[:2]
    #check color channels
    c = None if len(img.shape) < 3 else img.shape[2]
    #square images have an aspect ratio of 1:1
    if h == w: 
        return cv2.resize(img, (size, size), interpolation)
    elif h>w:#height is larger
        diff= h-w
        img=cv2.copyMakeBorder(img,0,0,int(diff/2.0),int(diff/2.0),cv2.BORDER_CONSTANT, value = 0)
        # img=cv2.copyMakeBorder(img,0,0,int(diff/2.0),int(diff/2.0),cv2.BORDER_REPLICATE)
    elif h<w:
        diff= w-h
        # img=cv2.copyMakeBorder(img,int(diff/2.0),int(diff/2.0),0,0,cv2.BORDER_REPLICATE)
        img=cv2.copyMakeBorder(img,int(diff/2.0),int(diff/2.0),0,0,cv2.BORDER_CONSTANT, value = 0)
    return cv2.resize(img, (size, size), interpolation)

# %%
import numpy as np

def scale_back(img, size=IMAGE_DIMS):
  h, w = img.shape[:2]
  c = None if len(img.shape) < 3 else img.shape[2]
  dif = size-h
  x_pos = int((dif)/2.0)
  y_pos = int((dif)/2.0)
  mask = np.zeros((size, size, c), dtype=img.dtype)
  mask[y_pos:y_pos+h, x_pos:x_pos+w, :] = img[:h, :w, :]
#   print(mask.shape)
  # cv2.imshow("test",mask)
  # cv2.waitKey(0)
  return mask

# %%
import numpy as np
import cv2
from tensorflow import keras

class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels, batch_size=32, dim=(IMAGE_DIMS,IMAGE_DIMS), n_channels=1,
                 n_classes=2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X = self.__data_generation(list_IDs_temp)
        return X

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples'
        x1 = np.empty((self.batch_size, IMAGE_DIMS,IMAGE_DIMS,3))
        x2 = np.empty((self.batch_size, IMAGE_DIMS,IMAGE_DIMS,3))
        # x1 = np.empty((self.batch_size, 3, IMAGE_DIMS,IMAGE_DIMS))
        # x2 = np.empty((self.batch_size, 3, IMAGE_DIMS,IMAGE_DIMS))
        y = np.empty((self.batch_size, 1))

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # print(self.labels[int(ID)])
            path1, path2, label, s1, s2 = self.labels[int(ID)]

            _x1 = cv2.imread(path1)
            _x2 = cv2.imread(path2)
            _x1 = preprocess(_x1, s1)
            _x1 = scale_back(_x1) / 255.
            _x2 = preprocess(_x2, s2)
            _x2 = scale_back(_x2) / 255.

            x1[i,] = _x1
            x2[i,] = _x2
            y[i,] = label
        return [x1, x2], y

# %%
import random
import numpy as np

def make_pairs():#makes pairs of data
    global pairs, classes, labels
    # pairs = np.array(pairs).astype("float32")
    # labels = np.array(labels).astype("float32")
    # pairs = []
    for class_ in classes:
        class_path = os.path.join(data_path, class_)
        for img_path in os.listdir(class_path):
            if np.random.uniform()<=0.25:#rescale images
                image1 = os.path.join(class_path, img_path)
                image_select=random.choice(os.listdir(class_path))
                image2 = os.path.join(class_path, image_select)
                scale = np.random.uniform(0.3,0.6)#scaling factor
                select_index = random.choice([1,2])
                if select_index==1:
                    s1=int(scale*IMAGE_DIMS)#scale down
                    s2 = IMAGE_DIMS
                    scale_flag=1
                else:
                    s2=int(scale*IMAGE_DIMS)#scale down
                    s1 = IMAGE_DIMS
                    scale_flag=2
                pairs+=[[image1, image2, 1, s1, s2]]

                class_select = random.choice(classes)
                while class_select == class_:# keep trying if select the current class
                    class_select = random.choice(classes)
                class_path2 = os.path.join(data_path, class_select)
                image_select=random.choice(os.listdir(class_path2))
                image2 = os.path.join(class_path2, image_select)
                if scale_flag ==1:
                    s1 = IMAGE_DIMS
                    if np.random.uniform()<0.5:
                        s2=int(scale*IMAGE_DIMS)#scale down
                    else:
                        s2 = IMAGE_DIMS
                elif scale_flag ==2:
                    if np.random.uniform()<0.5:
                        select_index = random.choice([1,2])
                        if select_index==1:
                            s1=int(scale*IMAGE_DIMS)#scale down
                            s2 = IMAGE_DIMS
                        else:
                            s2=int(scale*IMAGE_DIMS)#scale down
                            s1 = IMAGE_DIMS
                scale_flag=0
                pairs+=[[image1, image2, 0, s1, s2]]

            image1 = os.path.join(class_path, img_path)
            image_select=random.choice(os.listdir(class_path))
            image2 = os.path.join(class_path, image_select)
            # image1=preprocess(image1)
            # image2=preprocess(image2)
            pairs+=[[image1, image2, 1, IMAGE_DIMS, IMAGE_DIMS]]


            class_select = random.choice(classes)
            while class_select == class_:# keep trying if select the current class
                class_select = random.choice(classes)
            class_path2 = os.path.join(data_path, class_select)
            image_select=random.choice(os.listdir(class_path2))
            image2 = os.path.join(class_path2, image_select)
            # image2=preprocess(image2)
            pairs+=[[image1, image2, 0, IMAGE_DIMS, IMAGE_DIMS]]

# %%
make_pairs()

# %%
pairs
# Out:
# [['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/47.png',
#   1,
#   106,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1313/34.png',
#   0,
#   224,
#   106],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/17.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1597/39.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/13.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/47.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/13.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1409/22.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/28.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/62.png',
#   1,
#   224,
#   124],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/28.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1990/57.png',
#   0,
#   224,
#   124],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/28.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/38.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/28.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/738/35.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/23.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/46.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/23.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/333/32.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/18.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/14.png',
#   1,
#   224,
#   74],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/18.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/535/60.png',
#   0,
#   224,
#   74],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/18.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/32.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/18.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/229/25.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/32.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/59.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/32.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/615/53.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/59.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/20.png',
#   1,
#   224,
#   70],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/59.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/877/39.png',
#   0,
#   224,
#   70],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/59.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/43.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/59.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1923/25.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/61.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/60.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/61.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1507/36.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/47.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/25.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/47.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1958/70.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/50.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/65.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/50.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1483/24.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/67.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/32.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/67.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1905/10.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/57.png',
#   1,
#   224,
#   81],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1856/44.png',
#   0,
#   224,
#   81],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/39.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1762/44.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/50.png',
#   1,
#   224,
#   121],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/742/40.png',
#   0,
#   224,
#   121],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/44.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/424/38.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/16.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1273/8.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/60.png',
#   1,
#   98,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1127/47.png',
#   0,
#   224,
#   98],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/36.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1317/25.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/15.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1581/39.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/45.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/18.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/45.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/17/50.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/58.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1239/24.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/23.png',
#   1,
#   224,
#   76],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/942/9.png',
#   0,
#   224,
#   76],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/71.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/547/47.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/1.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/448/22.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/25.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/63.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/25.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1079/25.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/29.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/9.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/29.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1205/48.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/71.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/359/32.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/3.png',
#   1,
#   90,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/808/45.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/2.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/133/49.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/16.png',
#   1,
#   97,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/115/10.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/8.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1751/59.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/71.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/28.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/71.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/109/7.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/20.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/20.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/20.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/60/58.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/67.png',
#   1,
#   82,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1317/67.png',
#   0,
#   224,
#   82],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/43.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/802/68.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/15.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/59.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/15.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1667/9.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/39.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/70.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/39.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1049/57.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/13.png',
#   1,
#   117,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/400/42.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/46.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/663/10.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/63.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/6.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/63.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/645/58.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/30.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/13.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/30.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/773/6.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/8.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1757/54.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/40.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/19.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/40.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1740/16.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/37.png',
#   1,
#   224,
#   94],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1364/55.png',
#   0,
#   94,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/55.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1566/36.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/46.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/52.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/46.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1641/32.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/49.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1398/35.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/2.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/33.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/2.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1536/50.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/41.png',
#   1,
#   224,
#   98],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/615/29.png',
#   0,
#   224,
#   98],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/58.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1608/44.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/27.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/39.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/27.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1230/3.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/37.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/38.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/37.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1395/50.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/70.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/207/49.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/53.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/69/63.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/22.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/68.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/22.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1742/27.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/53.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/45.png',
#   1,
#   82,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/53.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/210/52.png',
#   0,
#   224,
#   82],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/53.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/70.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/53.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1322/28.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/67.png',
#   1,
#   120,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/141/5.png',
#   0,
#   224,
#   120],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/3.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1033/16.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/49.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/40.png',
#   1,
#   224,
#   119],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/49.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/184/6.png',
#   0,
#   119,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/49.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/27.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/49.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/677/40.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/7.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/39.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/7.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1705/55.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/31.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/18.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/31.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/890/39.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/66.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/44.png',
#   1,
#   125,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/66.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/694/32.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/66.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/39.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/66.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/167/28.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/21.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/30.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/21.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/7/19.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/26.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/0.png',
#   1,
#   224,
#   77],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/26.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/892/36.png',
#   0,
#   77,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/26.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/38.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/26.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1073/35.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/42.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/6.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/42.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1630/6.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/48.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/65.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/48.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1334/59.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/62.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/47.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/62.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1226/6.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/17.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/38.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/17.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/611/47.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/51.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/9.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/51.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/811/63.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/14.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/64.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/14.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/440/55.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/3.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/10.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/3.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/451/43.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/58.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/43.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/58.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1343/10.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/34.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/33.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/34.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1737/4.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/60.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/40.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/60.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1478/71.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/54.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/49.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/54.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1467/0.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/11.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/55.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/11.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1085/20.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/36.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/13.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/36.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1455/1.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/4.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/23.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/4.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1872/5.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/9.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/27.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/9.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/435/71.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/65.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/39.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/65.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1515/67.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/6.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/17.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/6.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1416/64.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/16.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/23.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/16.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/528/71.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/55.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/71.png',
#   1,
#   72,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/55.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1326/67.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/55.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/34.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/55.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/315/31.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/55.png',
#   1,
#   224,
#   76],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1035/32.png',
#   0,
#   76,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/25.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/68.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/294/44.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/13.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/22.png',
#   1,
#   224,
#   105],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/13.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/10/30.png',
#   0,
#   224,
#   105],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/13.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/67.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/13.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/306/34.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/28.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/70.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/28.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1616/45.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/23.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/13.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/23.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/359/7.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/18.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/2.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/18.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/991/62.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/32.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/19.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/32.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/430/49.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/59.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/46.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/59.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/997/11.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/61.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/23.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/61.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/729/67.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/47.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/34.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/47.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1770/59.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/50.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/59.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/50.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1694/36.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/67.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/52.png',
#   1,
#   110,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/67.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/436/60.png',
#   0,
#   224,
#   110],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/67.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/37.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/67.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/382/30.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/58.png',
#   1,
#   224,
#   67],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/425/51.png',
#   0,
#   67,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/57.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/629/24.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/14.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1281/13.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/9.png',
#   1,
#   224,
#   73],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1086/3.png',
#   0,
#   224,
#   73],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/69.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/99/52.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/55.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1580/35.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/3.png',
#   1,
#   77,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/228/48.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/66.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/709/32.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/45.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/53.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/45.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/20/25.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/34.png',
#   1,
#   224,
#   132],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1092/67.png',
#   0,
#   224,
#   132],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/60.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1227/7.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/62.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1828/31.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/45.png',
#   1,
#   224,
#   124],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/887/64.png',
#   0,
#   224,
#   124],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/65.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1965/50.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/25.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/63.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/25.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/172/33.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/29.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/5.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/29.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1958/43.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/23.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/535/25.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/60.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1025/29.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/30.png',
#   1,
#   128,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1566/45.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/54.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/51/12.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/71.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/44.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/71.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1141/15.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/20.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/17.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/20.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1598/14.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/24.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1420/48.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/15.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/61.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/15.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/418/3.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/39.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/58.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/39.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1043/14.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/56.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1572/20.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/63.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/29.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/63.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1331/44.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/30.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/4.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/30.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1000/2.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/26.png',
#   1,
#   118,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1538/24.png',
#   0,
#   224,
#   118],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/68.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1320/29.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/40.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/9.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/40.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/997/28.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/50.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/228/19.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/46.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/11.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/46.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1943/60.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/34.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/349/21.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/2.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/56.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/2.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1727/35.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/61.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/271/15.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/27.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/16.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/27.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1749/64.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/37.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/59.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/37.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1972/35.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/0.png',
#   1,
#   224,
#   123],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1147/58.png',
#   0,
#   123,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/31.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/134/70.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/1.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/931/33.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/22.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/13.png',
#   1,
#   224,
#   107],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/22.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1670/26.png',
#   0,
#   224,
#   107],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/22.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1491/32.png',
#   1,
#   224,
#   224],
# ...
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/67.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1199/43.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/43.png',
#   1,
#   224,
#   76],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1657/55.png',
#   0,
#   224,
#   76],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/25.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/52.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1268/1.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/43.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/1.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1414/23.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/53.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/24.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1253/20.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/54.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/41.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1069/28.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/13.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/64.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/201/53.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/45.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/26.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/45.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/969/16.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/12.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/57.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1260/61.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/7.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/8.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1358/41.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/65.png',
#   1,
#   116,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1982/27.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/15.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/920/29.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/25.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/61.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/25.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1247/13.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/29.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/25.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/29.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1671/65.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/12.png',
#   1,
#   224,
#   113],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/488/8.png',
#   0,
#   224,
#   113],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/34.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1960/68.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/60.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/44.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/250/65.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/71.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/35.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/141/5.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/71.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/71.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/71.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/434/30.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/20.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/29.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/20.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/991/59.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/26.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/5.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1790/6.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/15.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/5.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/15.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/749/23.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/39.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/56.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/39.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/377/59.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/56.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/0.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/957/42.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/63.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/44.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/63.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/397/60.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/30.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/5.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/30.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/862/38.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/48.png',
#   1,
#   128,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1183/11.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/46.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/33.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1332/69.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/40.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/52.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/40.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1739/9.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/36.png',
#   1,
#   224,
#   130],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1378/50.png',
#   0,
#   224,
#   130],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/12.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/70.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1236/61.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/46.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/0.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/46.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1475/65.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/67.png',
#   1,
#   84,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1990/71.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/12.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/38.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1591/56.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/2.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/19.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/2.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1657/44.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/59.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/43.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/544/9.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/27.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/48.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/27.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1124/55.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/37.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/47.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/37.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1964/13.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/7.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/56.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/231/2.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/9.png',
#   1,
#   93,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/320/65.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/19.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/10.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1132/10.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/22.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/1.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/22.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1459/67.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/53.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/0.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/53.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/786/42.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/12.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/39.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/12.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1601/63.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/49.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/45.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/49.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/994/2.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/7.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/43.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/7.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1483/63.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/31.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/23.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/31.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1234/67.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/66.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/54.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/66.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/272/29.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/21.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/53.png',
#   1,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/21.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1087/46.png',
#   0,
#   224,
#   224],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/26.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/63.png',
#   1,
#   224,
#   83],
#  ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1342/26.png',
#   '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1867/49.png',
#   0,
#   224,
#   83],
#  ...]

# %%
pairs_len = len(pairs)
print(len(pairs))
print(pairs[0])
# Out:
# 1080370
# ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/68.png', '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/1634/47.png', 1, 106, 224]

# %%
print(pairs[pairs_len-1])
# Out:
# ['/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/256/55.png', '/home/halim/Documents/ECE613/GitHub/Face_id_meta/data/447/60.png', 0, 224, 224]

# %%
#60/20/20
import math

# partition = {'train': np.arange(len(pairs)*.6),
#              'validation': np.arange(len(pairs)*.6,len(pairs)*.8),
#              'test': np.arange(len(pairs)*.8, len(pairs))}

partition = {'train': np.arange(math.floor(len(pairs)*.6)),
             'validation': np.arange(math.floor(len(pairs)*.6),math.floor(len(pairs)*.8)),
             'test': np.arange(math.floor(len(pairs)*.8), math.floor(len(pairs)))}

# %%
partition
# Out:
# {'train': array([     0,      1,      2, ..., 648219, 648220, 648221]),
#  'validation': array([648222, 648223, 648224, ..., 864293, 864294, 864295]),
#  'test': array([ 864296,  864297,  864298, ..., 1080367, 1080368, 1080369])}

# %%
# Generators
train_generator = DataGenerator(partition['train'], pairs, batch_size=16)
val_generator = DataGenerator(partition['validation'], pairs, batch_size=16)

# %%
print(len(train_generator)) 
print(len(train_generator[0])) # number of batches
print(len(train_generator[0][1])) # access images or label # return [x1, x2], y (0 to 1)
print(len(train_generator[0][0][0])) # choose image here x1 or x2 (0 to 1)
print(len(train_generator[0][0][0][15])) # which item in batch 0 to 15
print(len(train_generator[0][0][0][0][223])) # 0 to 224
print(len(train_generator[0][0][0][0][0][223])) # 0 to 224
# print(len(train_generator[0][0][0][0][0][0][0]))
# Out:
# 40513
# 2
# 16
# 16
# 224
# 224
# 3

# %%
print(len(train_generator)) 
print(len(train_generator[0])) 
print(len(train_generator[0][1])) # access images or label # return [x1, x2], y (0 to 1)
print(len(train_generator[0][1][15])) # which item in batch 0 to 15
# Out:
# 40513
# 2
# 16
# 1

# %%
# test_x1 = np.empty((10, 4,4,2))
# test_x2 = np.empty((10, 4,4,2))
# test_y = np.empty((10, 1))

# %%
# for i in range(0,10):
#     test_x1[i,] = 1

# test_x1

# %%
import matplotlib.pyplot as plt

#2*16*224*224*3
#first index: which batch
#2nd index: image or label
#3rd index: which image of the pair (x1 or x2)
#4th index: which element of the batch
img = train_generator[0][0][1][0]
label = train_generator[0][1]
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = train_generator[0][0][1][0]
img.shape
# Out:
# (224, 224, 3)

# %%
b_img = np.transpose(img, (2, 0, 1))
b_img.shape
# Out:
# (3, 224, 224)

# %%
train_generator[0][0][0]
# Out:
# array([[[[0.80392157, 0.79607843, 0.78823529],
#          [0.80392157, 0.79607843, 0.78823529],
#          [0.80392157, 0.79607843, 0.78823529],
#          ...,
#          [0.05098039, 0.04705882, 0.04313725],
#          [0.05490196, 0.05098039, 0.04705882],
#          [0.05490196, 0.05098039, 0.04705882]],
#
#         [[0.80392157, 0.79607843, 0.78823529],
#          [0.80392157, 0.79607843, 0.78823529],
#          [0.80392157, 0.79607843, 0.78823529],
#          ...,
#          [0.05098039, 0.04705882, 0.04313725],
#          [0.05098039, 0.04705882, 0.04313725],
#          [0.05490196, 0.05098039, 0.04705882]],
#
#         [[0.80392157, 0.79607843, 0.78431373],
#          [0.80392157, 0.79607843, 0.78431373],
#          [0.80392157, 0.79607843, 0.78823529],
#          ...,
#          [0.04705882, 0.04313725, 0.03921569],
#          [0.05098039, 0.04705882, 0.04313725],
#          [0.05098039, 0.04705882, 0.04313725]],
#
#         ...,
#
#         [[0.69411765, 0.72941176, 0.7254902 ],
#          [0.69411765, 0.72941176, 0.7254902 ],
#          [0.69411765, 0.72941176, 0.7254902 ],
#          ...,
#          [0.67058824, 0.69803922, 0.69019608],
#          [0.67843137, 0.70196078, 0.69411765],
#          [0.68235294, 0.70588235, 0.69803922]],
#
#         [[0.69019608, 0.7254902 , 0.72156863],
#          [0.69019608, 0.7254902 , 0.72156863],
#          [0.69019608, 0.7254902 , 0.7254902 ],
#          ...,
#          [0.67058824, 0.69411765, 0.68627451],
#          [0.6745098 , 0.70196078, 0.69411765],
#          [0.67843137, 0.70588235, 0.69803922]],
#
#         [[0.69019608, 0.7254902 , 0.72156863],
#          [0.69019608, 0.7254902 , 0.72156863],
#          [0.69019608, 0.7254902 , 0.7254902 ],
#          ...,
#          [0.67058824, 0.69411765, 0.68627451],
#          [0.6745098 , 0.70196078, 0.69411765],
#          [0.67843137, 0.70588235, 0.69803922]]],
#
#
#        [[[0.46666667, 0.5372549 , 0.47058824],
#          [0.46666667, 0.5372549 , 0.47058824],
#          [0.46666667, 0.54117647, 0.4745098 ],
#          ...,
#          [0.11372549, 0.10196078, 0.10196078],
#          [0.14901961, 0.12941176, 0.1254902 ],
#          [0.16470588, 0.14509804, 0.1372549 ]],
#
#         [[0.46666667, 0.5372549 , 0.47058824],
#          [0.46666667, 0.5372549 , 0.47058824],
#          [0.46666667, 0.54117647, 0.4745098 ],
#          ...,
#          [0.10980392, 0.09803922, 0.09803922],
#          [0.14117647, 0.1254902 , 0.11764706],
#          [0.15294118, 0.1372549 , 0.12941176]],
#
#         [[0.46666667, 0.5372549 , 0.47058824],
#          [0.46666667, 0.5372549 , 0.47058824],
#          [0.46666667, 0.54117647, 0.4745098 ],
#          ...,
#          [0.10196078, 0.09411765, 0.09019608],
#          [0.12156863, 0.10980392, 0.10588235],
#          [0.13333333, 0.11764706, 0.11372549]],
#
#         ...,
#
#         [[0.34901961, 0.49019608, 0.34509804],
#          [0.34901961, 0.49019608, 0.34509804],
#          [0.34509804, 0.48627451, 0.34509804],
#          ...,
#          [0.61568627, 0.63921569, 0.66666667],
#          [0.62745098, 0.65490196, 0.67843137],
#          [0.63529412, 0.65882353, 0.68235294]],
#
#         [[0.35294118, 0.49019608, 0.34509804],
#          [0.34901961, 0.49019608, 0.34509804],
#          [0.34901961, 0.48627451, 0.34117647],
#          ...,
#          [0.60392157, 0.63137255, 0.6627451 ],
#          [0.62352941, 0.64705882, 0.67058824],
#          [0.63137255, 0.65490196, 0.67843137]],
#
#         [[0.35294118, 0.49019608, 0.34509804],
#          [0.35294118, 0.49019608, 0.34509804],
#          [0.34901961, 0.48627451, 0.34117647],
#          ...,
#          [0.6       , 0.62745098, 0.65882353],
#          [0.61960784, 0.64313725, 0.67058824],
#          [0.62745098, 0.65098039, 0.6745098 ]]],
#
#
#        [[[0.89411765, 0.86666667, 0.84705882],
#          [0.89411765, 0.86666667, 0.84705882],
#          [0.89019608, 0.8627451 , 0.84313725],
#          ...,
#          [0.96470588, 0.96470588, 0.96078431],
#          [0.96470588, 0.96470588, 0.96470588],
#          [0.96470588, 0.96470588, 0.96470588]],
#
#         [[0.89411765, 0.86666667, 0.84705882],
#          [0.89411765, 0.86666667, 0.84705882],
#          [0.89019608, 0.86666667, 0.84705882],
#          ...,
#          [0.96470588, 0.96470588, 0.96078431],
#          [0.96470588, 0.96470588, 0.96470588],
#          [0.96470588, 0.96470588, 0.96470588]],
#
#         [[0.89411765, 0.87058824, 0.85098039],
#          [0.89411765, 0.87058824, 0.85098039],
#          [0.89411765, 0.87058824, 0.85098039],
#          ...,
#          [0.96470588, 0.96470588, 0.96470588],
#          [0.96078431, 0.96470588, 0.96078431],
#          [0.96078431, 0.96470588, 0.96078431]],
#
#         ...,
#
#         [[0.3372549 , 0.30588235, 0.34901961],
#          [0.3372549 , 0.30588235, 0.34901961],
#          [0.33333333, 0.30196078, 0.34901961],
#          ...,
#          [0.38431373, 0.44705882, 0.45882353],
#          [0.38431373, 0.45098039, 0.45882353],
#          [0.38431373, 0.45490196, 0.45882353]],
#
#         [[0.32156863, 0.29411765, 0.34117647],
#          [0.32156863, 0.29019608, 0.34117647],
#          [0.31764706, 0.29019608, 0.3372549 ],
#          ...,
#          [0.38823529, 0.45098039, 0.4627451 ],
#          [0.38823529, 0.45490196, 0.4627451 ],
#          [0.38823529, 0.45882353, 0.4627451 ]],
#
#         [[0.31372549, 0.28627451, 0.3372549 ],
#          [0.31372549, 0.28627451, 0.3372549 ],
#          [0.30980392, 0.28235294, 0.33333333],
#          ...,
#          [0.38823529, 0.45098039, 0.4627451 ],
#          [0.38823529, 0.45490196, 0.4627451 ],
#          [0.38823529, 0.45882353, 0.4627451 ]]],
#
#
#        ...,
#
#
#        [[[0.10588235, 0.11372549, 0.09019608],
#          [0.10588235, 0.11372549, 0.09019608],
#          [0.10588235, 0.11372549, 0.09411765],
#          ...,
#          [0.33333333, 0.42745098, 0.47843137],
#          [0.33333333, 0.42745098, 0.47843137],
#          [0.33333333, 0.42745098, 0.47843137]],
#
#         [[0.10588235, 0.11372549, 0.09019608],
#          [0.10588235, 0.11372549, 0.09019608],
#          [0.10588235, 0.11372549, 0.09019608],
#          ...,
#          [0.33333333, 0.42745098, 0.47843137],
#          [0.33333333, 0.42745098, 0.47843137],
#          [0.33333333, 0.42745098, 0.47843137]],
#
#         [[0.10196078, 0.10980392, 0.08627451],
#          [0.10196078, 0.10980392, 0.08627451],
#          [0.10196078, 0.10980392, 0.08627451],
#          ...,
#          [0.3372549 , 0.42745098, 0.47843137],
#          [0.33333333, 0.42352941, 0.47843137],
#          [0.33333333, 0.42352941, 0.4745098 ]],
#
#         ...,
#
#         [[0.36078431, 0.29803922, 0.27058824],
#          [0.36470588, 0.30196078, 0.2745098 ],
#          [0.36862745, 0.30980392, 0.28627451],
#          ...,
#          [0.21568627, 0.30980392, 0.36470588],
#          [0.21176471, 0.31764706, 0.37647059],
#          [0.21176471, 0.32156863, 0.38431373]],
#
#         [[0.35686275, 0.29411765, 0.2627451 ],
#          [0.36078431, 0.29803922, 0.27058824],
#          [0.36862745, 0.30980392, 0.28235294],
#          ...,
#          [0.21960784, 0.29411765, 0.34509804],
#          [0.21568627, 0.30980392, 0.36470588],
#          [0.21568627, 0.31764706, 0.37254902]],
#
#         [[0.35294118, 0.29019608, 0.25882353],
#          [0.35686275, 0.29411765, 0.26666667],
#          [0.36862745, 0.30588235, 0.27843137],
#          ...,
#          [0.22352941, 0.28627451, 0.33333333],
#          [0.21960784, 0.30588235, 0.35686275],
#          [0.21568627, 0.31372549, 0.36862745]]],
#
#
#        [[[0.39607843, 0.52156863, 0.60392157],
#          [0.39607843, 0.5254902 , 0.60784314],
#          [0.4       , 0.52941176, 0.61176471],
#          ...,
#          [0.22352941, 0.52156863, 0.61568627],
#          [0.22352941, 0.52156863, 0.61568627],
#          [0.22352941, 0.52156863, 0.61568627]],
#
#         [[0.4       , 0.5254902 , 0.60784314],
#          [0.4       , 0.5254902 , 0.60784314],
#          [0.40392157, 0.53333333, 0.61568627],
#          ...,
#          [0.22352941, 0.52156863, 0.61568627],
#          [0.22352941, 0.52156863, 0.61568627],
#          [0.22352941, 0.52156863, 0.61568627]],
#
#         [[0.40784314, 0.52941176, 0.61176471],
#          [0.40784314, 0.53333333, 0.61176471],
#          [0.41176471, 0.5372549 , 0.61960784],
#          ...,
#          [0.22352941, 0.52156863, 0.61568627],
#          [0.22352941, 0.5254902 , 0.61568627],
#          [0.22352941, 0.5254902 , 0.61568627]],
#
#         ...,
#
#         [[0.34117647, 0.56078431, 0.64705882],
#          [0.36470588, 0.57254902, 0.6627451 ],
#          [0.41960784, 0.59215686, 0.69803922],
#          ...,
#          [0.23529412, 0.50196078, 0.59607843],
#          [0.23529412, 0.50588235, 0.59607843],
#          [0.23529412, 0.50588235, 0.59607843]],
#
#         [[0.35686275, 0.56862745, 0.65490196],
#          [0.38431373, 0.58039216, 0.6745098 ],
#          [0.43529412, 0.60392157, 0.70980392],
#          ...,
#          [0.23529412, 0.50588235, 0.6       ],
#          [0.23529412, 0.50196078, 0.59607843],
#          [0.23529412, 0.50196078, 0.59607843]],
#
#         [[0.36470588, 0.57254902, 0.65882353],
#          [0.39215686, 0.58431373, 0.67843137],
#          [0.44313725, 0.61176471, 0.71372549],
#          ...,
#          [0.23529412, 0.50588235, 0.6       ],
#          [0.23529412, 0.50196078, 0.59607843],
#          [0.23529412, 0.50196078, 0.59607843]]],
#
#
#        [[[0.86666667, 0.83529412, 0.75686275],
#          [0.86666667, 0.83529412, 0.75686275],
#          [0.86666667, 0.83529412, 0.76078431],
#          ...,
#          [0.89019608, 0.8627451 , 0.80392157],
#          [0.89019608, 0.8627451 , 0.80392157],
#          [0.89019608, 0.8627451 , 0.80392157]],
#
#         [[0.86666667, 0.83529412, 0.75686275],
#          [0.86666667, 0.83529412, 0.75686275],
#          [0.86666667, 0.83529412, 0.76078431],
#          ...,
#          [0.89019608, 0.8627451 , 0.80392157],
#          [0.89019608, 0.8627451 , 0.80392157],
#          [0.89019608, 0.8627451 , 0.80392157]],
#
#         [[0.86666667, 0.83529412, 0.76078431],
#          [0.86666667, 0.83529412, 0.76078431],
#          [0.86666667, 0.83529412, 0.76078431],
#          ...,
#          [0.88627451, 0.85882353, 0.8       ],
#          [0.89019608, 0.8627451 , 0.80392157],
#          [0.89019608, 0.8627451 , 0.80392157]],
#
#         ...,
#
#         [[0.17254902, 0.20392157, 0.21176471],
#          [0.17254902, 0.20392157, 0.21176471],
#          [0.17254902, 0.20392157, 0.21568627],
#          ...,
#          [0.14117647, 0.15294118, 0.14901961],
#          [0.1372549 , 0.14509804, 0.14509804],
#          [0.1372549 , 0.14509804, 0.14509804]],
#
#         [[0.17254902, 0.2       , 0.21176471],
#          [0.17254902, 0.2       , 0.21176471],
#          [0.17254902, 0.20392157, 0.21568627],
#          ...,
#          [0.14117647, 0.15294118, 0.14901961],
#          [0.1372549 , 0.14901961, 0.14509804],
#          [0.1372549 , 0.14509804, 0.14509804]],
#
#         [[0.17254902, 0.2       , 0.21176471],
#          [0.17254902, 0.2       , 0.21176471],
#          [0.17254902, 0.20392157, 0.21568627],
#          ...,
#          [0.14117647, 0.15294118, 0.14901961],
#          [0.1372549 , 0.14901961, 0.14509804],
#          [0.1372549 , 0.14509804, 0.14509804]]]])

# %% [markdown]
# ### Pre-trained Model
#
# In this example are we going to fine-tune the [google/vit-base-patch16-224-in21k](https://huggingface.co/google/vit-base-patch16-224-in21k) a Vision Transformer (ViT) pre-trained on ImageNet-21k (14 million images, 21,843 classes) at resolution 224x224.
#
# You can easily adjust the `model_id` to another Vision Transformer model, e.g. `google/vit-base-patch32-384`

# %%
model_id = "google/vit-base-patch16-224-in21k"

# %% [markdown]
# ### Pre-processing
#
# To train our model we need to convert our "Images" to `pixel_values`. This is done by a [🤗 Transformers Feature Extractor](https://huggingface.co/docs/transformers/master/en/main_classes/feature_extractor#feature-extractor) which allows us to `augment` and convert the images into a 3D Array to be fed into our model.

# %%
# from transformers import ViTFeatureExtractor
# from tensorflow import keras 
# from tensorflow.keras import layers


# feature_extractor = ViTFeatureExtractor.from_pretrained(model_id)

# # learn more about data augmentation here: https://www.tensorflow.org/tutorials/images/data_augmentation
# data_augmentation = keras.Sequential(
#     [
#         layers.Resizing(feature_extractor.size, feature_extractor.size),
#         layers.Rescaling(1./255),
#         layers.RandomFlip("horizontal"),
#         layers.RandomRotation(factor=0.02),
#         layers.RandomZoom(
#             height_factor=0.2, width_factor=0.2
#         ),
#     ],
#     name="data_augmentation",
# )
# # use keras image data augementation processing
# def augmentation(examples):
#     # print(examples["img"])
#     examples["pixel_values"] = [data_augmentation(image) for image in examples["img"]]
#     return examples


# # basic processing (only resizing)
# def process(examples):
#     examples.update(feature_extractor(examples['img'], ))
#     return examples

# %%
import tensorflow as tf
from tensorflow.keras import layers

class L1Dist(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return tf.math.abs(embedding1-embedding2)


class L1Dist_mod(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return tf.math.reduce_sum(tf.math.abs(embedding1-embedding2), axis=1, keepdims=True)

class L2Dist(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        sum_square = tf.math.reduce_sum(tf.math.square(embedding1 - embedding2), axis=1, keepdims=True)
        return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))

class cosine(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return 1-tf.keras.losses.cosine_similarity(embedding1,embedding2)

class TF_L2Dist(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return tf.math.reduce_euclidean_norm(embedding1,embedding2)

# %% [markdown]
# ### Download the pretrained transformer model and fine-tune it.

# %%
# from transformers import TFViTForImageClassification, create_optimizer
# import tensorflow as tf

# # create optimizer wight weigh decay
# num_train_steps = len(tf_train_dataset) * num_train_epochs
# optimizer, lr_schedule = create_optimizer(
#     init_lr=learning_rate,
#     num_train_steps=num_train_steps,
#     weight_decay_rate=weight_decay_rate,
#     num_warmup_steps=num_warmup_steps,
# )

# # load pre-trained ViT model
# model = TFViTForImageClassification.from_pretrained(
#     model_id,
#     num_labels=len(img_class_labels),
#     id2label=id2label,
#     label2id=label2id,
# )

# # define loss
# loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # define metrics 
# metrics=[
#     tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
#     tf.keras.metrics.SparseTopKCategoricalAccuracy(3, name="top-3-accuracy"),
# ]

# # compile model
# model.compile(optimizer=optimizer,
#               loss=loss,
#               metrics=metrics
#               )

# %% [markdown]
# If you want to create you own classification head or if you want to add the augmentation/processing layer to your model, you can directly use the [functional Keras API](https://keras.io/guides/functional_api/). Below you find an example on how you would create a classification head.

# %%
# import tensorflow as tf
# from transformers import TFViTModel

# base_model = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')

# %%
# base_model.summary()

# %%
# alternatively create Image Classification model using Keras Layer and ViTModel 
# here you can also add the processing layers of keras

import tensorflow as tf
from transformers import TFViTModel
from tensorflow.keras import regularizers
from tensorflow.keras import layers

def make_siamese_net():
    base_model = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
    # base_model.summary()

    # inputs
    pixel_values1 = tf.keras.layers.Input(shape=(IMAGE_DIMS,IMAGE_DIMS, 3), name='pixel_values1', dtype='float32')
    pixel_values2 = tf.keras.layers.Input(shape=(IMAGE_DIMS,IMAGE_DIMS, 3), name='pixel_values2', dtype='float32')

    # b_img = np.transpose(img, (2, 0, 1))
    # b_img = np.transpose(img, (2, 0, 1))
    p1 = layers.Permute((3, 1, 2), input_shape=(IMAGE_DIMS,IMAGE_DIMS, 3))(pixel_values1)
    p2 = layers.Permute((3, 1, 2), input_shape=(IMAGE_DIMS,IMAGE_DIMS, 3))(pixel_values2)
  

    # model layer
    # vit = base_model.vit(pixel_values)[0]
    vit1 = base_model.vit(p1)[0]
    vit2 = base_model.vit(p2)[0]

    x1 = layers.Dense(1024, activation='sigmoid',kernel_regularizer=regularizers.l2(1e-3))(vit1)
    x2 = layers.Dense(1024, activation='sigmoid',kernel_regularizer=regularizers.l2(1e-3))(vit2)

    siamese_layer=L1Dist_mod()
    distances=siamese_layer(x1, x2)

    # classifier = tf.keras.layers.Dense(1, activation='softmax', name='outputs')(distances)
    classifier = tf.keras.layers.Dense(1, activation='sigmoid', name='outputs')(distances)

    # model
    keras_model = tf.keras.Model(inputs=[pixel_values1,pixel_values2] , outputs=classifier,name="siamese_network")

    return keras_model

# %%
def loss(margin=1):
    """Provides 'constrastive_loss' an enclosing scope with variable 'margin'.

  Arguments:
      margin: Integer, defines the baseline for distance for which pairs
              should be classified as dissimilar. - (default is 1).

  Returns:
      'constrastive_loss' function with data ('margin') attached.
  """

    # Contrastive loss = mean( (1-true_value) * square(prediction) +
    #                         true_value * square( max(margin-prediction, 0) ))
    def contrastive_loss(y_true, y_pred):
        """Calculates the constrastive loss.

      Arguments:
          y_true: List of labels, each label is of type float32.
          y_pred: List of predictions of same length as of y_true,
                  each label is of type float32.

      Returns:
          A tensor containing constrastive loss as floating point value.
      """

        square_pred = tf.math.square(y_pred)
        margin_square = tf.math.square(tf.math.maximum(margin - (y_pred), 0))
        return tf.math.reduce_mean(
            (1 - y_true) * square_pred + (y_true) * margin_square
        )

    return contrastive_loss

# %%
siamese_net=make_siamese_net()
siamese_net.summary()
# Out:
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.
# Model: "siamese_network"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  pixel_values1 (InputLayer)     [(None, 224, 224, 3  0           []
#                                 )]
#
#  pixel_values2 (InputLayer)     [(None, 224, 224, 3  0           []
#                                 )]
#
#  permute_6 (Permute)            (None, 3, 224, 224)  0           ['pixel_values1[0][0]']
#
#  permute_7 (Permute)            (None, 3, 224, 224)  0           ['pixel_values2[0][0]']
#
#  vit (TFViTMainLayer)           TFBaseModelOutputWi  86389248    ['permute_6[0][0]',
#                                 thPooling(last_hidd               'permute_7[0][0]']
#                                 en_state=(None, 197
#                                 , 768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  hidden_states=None
#                                 , attentions=None)
#
#  dense_10 (Dense)               (None, 197, 1024)    787456      ['vit[0][0]']
#
#  dense_11 (Dense)               (None, 197, 1024)    787456      ['vit[1][0]']
#
#  l1_dist_mod_5 (L1Dist_mod)     (None, 1, 1024)      0           ['dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
#  outputs (Dense)                (None, 1, 1)         1025        ['l1_dist_mod_5[0][0]']
#
# ==================================================================================================
# Total params: 87,965,185
# Trainable params: 87,965,185
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# siamese_net.add_loss(loss(1))
siamese_net.compile(loss=loss(1), optimizer=tf.keras.optimizers.Adam(learning_rate=0.5e-6), 
                    metrics=["accuracy"])

# %%
from keras.callbacks import ModelCheckpoint

checkpoint_path = os.path.join(home, 'checkpoints')
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
early_callback=tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",patience=35, restore_best_weights=True)

# %%
from keras.callbacks import LearningRateScheduler

# callbacks_list = [early_callback,checkpoint]
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        lr = lr * tf.math.exp(-0.05)
        if lr >= 1e-8:
            return lr
        else:
            return 1e-8
# 0.5e-7

class print_lr(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(keras.backend.eval(self.model.optimizer.lr))

lr_sched = LearningRateScheduler(scheduler)

callbacks_list = [early_callback, lr_sched, checkpoint, print_lr()]

# %%
# Fit the model
# siamese_net = keras.models.load_model('checkpoints', custom_objects={ 'contrastive_loss': loss(1) })

batch_size=32
epochs=500
history = siamese_net.fit(
    train_generator,
    validation_data=val_generator,
    callbacks=callbacks_list,
    epochs=epochs,
)
# history = siamese_net.fit(
#     [x_train_1, x_train_2],
#     y_train,
#     validation_data=([x_val_1, x_val_2], y_val),
#     batch_size=batch_size,
#     callbacks=callbacks_list,
#     epochs=epochs,
#     # sample_weight=sample_weight,
# )

print(max(history.history["val_accuracy"]))
# Out:
# Epoch 1/500
# WARNING:tensorflow:Gradients do not exist for variables ['tf_vi_t_model_9/vit/pooler/dense/kernel:0', 'tf_vi_t_model_9/vit/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_vi_t_model_9/vit/pooler/dense/kernel:0', 'tf_vi_t_model_9/vit/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_vi_t_model_9/vit/pooler/dense/kernel:0', 'tf_vi_t_model_9/vit/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_vi_t_model_9/vit/pooler/dense/kernel:0', 'tf_vi_t_model_9/vit/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
#     2/40513 [..............................] - ETA: 224:10:55 - loss: 2.1930 - accuracy: 0.5625
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#https://github.com/huggingface/transformers/issues/2256
