# %%
# !pip install tensorflow
# !pip install transformers tensorboard --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (2.11.0)
# Requirement already satisfied: packaging in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (0.30.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 6.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (23.1.21)
# Requirement already satisfied: wrapt>=1.11.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/halim/.local/lib/python3.10/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/halim/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Installing collected packages: tensorboard-data-server, tensorboard
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.0
#     Uninstalling tensorboard-2.12.0:
#       Successfully uninstalled tensorboard-2.12.0
# Successfully installed tensorboard-2.11.2 tensorboard-data-server-0.6.1
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (4.26.1)
# Requirement already satisfied: tensorboard in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (2.11.2)
# Collecting tensorboard
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 8.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (22.0)
# Requirement already satisfied: filelock in /home/halim/.local/lib/python3.10/site-packages (from transformers) (3.8.2)
# Requirement already satisfied: requests in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (0.11.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /home/halim/.local/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: setuptools>=41.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (65.6.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /home/halim/.local/lib/python3.10/site-packages (from tensorboard) (1.3.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (2.16.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: protobuf>=3.19.6 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (3.19.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (2.2.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 9.8 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: markdown>=2.6.8 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: wheel>=0.26 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (0.38.4)
# Requirement already satisfied: grpcio>=1.48.2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/halim/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/halim/.local/lib/python3.10/site-packages (from requests->transformers) (1.26.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.2)
# Installing collected packages: tensorboard-data-server, tensorboard
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.12.0 which is incompatible.
# tensorflow-cpu 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.12.0 which is incompatible.
# Successfully installed tensorboard-2.12.0 tensorboard-data-server-0.7.0

# %% [markdown]
# ### DigiFace-1M Dataset
#
# https://github.com/microsoft/DigiFace1M
#
# The DigiFace-1M dataset is a collection of over one million diverse synthetic face images for face recognition.
#
# It was introduced in our paper DigiFace-1M: 1 Million Digital Face Images for Face Recognition and can be used to train deep learning models for facial recognition.
#
# The dataset contains:
#
#     720K images with 10K identities (72 images per identity). For each identity, 4 different sets of accessories are sampled and 18 images are rendered for each set.
#     500K images with 100K identities (5 images per identity). For each identity, only one set of accessories is sampled.
#
# The DigiFace-1M dataset can be used for non-commercial research, and is licensed under the license found in LICENSE.

# %%
import os

home=os.path.abspath(os.getcwd())
data_path=os.path.join(home, 'data')

#global data
pairs=[]
classes=[]
IMAGE_DIMS = 112 # was 224 pixels

for file in os.listdir(data_path):
    classes.append(file)

# %%
# print(os.listdir(data_path))

# %%
print(len(classes))
# Out:
# 2000

# %%
import numpy as np

class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels, batch_size=32, dim=(IMAGE_DIMS,IMAGE_DIMS), n_channels=1,
                 n_classes=2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X = self.__data_generation(list_IDs_temp)
        return X

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples'
        x1 = np.empty((self.batch_size, IMAGE_DIMS,IMAGE_DIMS,3))
        x2 = np.empty((self.batch_size, IMAGE_DIMS,IMAGE_DIMS,3))
        y = np.empty((self.batch_size, 1))

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # print(self.labels[int(ID)])
            path1, path2, label, s1, s2 = self.labels[int(ID)]

            _x1 = cv2.imread(path1)
            _x2 = cv2.imread(path2)
            _x1 = preprocess(_x1, s1)
            _x1 = scale_back(_x1) / 255.
            _x2 = preprocess(_x2, s2)
            _x2 = scale_back(_x2) / 255.

            x1[i,] = _x1
            x2[i,] = _x2
            y[i,] = label
        return [x1, x2], y

# %%
import random
import numpy as np

def make_pairs():#makes pairs of data
    global pairs, classes, labels
    # pairs = np.array(pairs).astype("float32")
    # labels = np.array(labels).astype("float32")
    # pairs = []
    for class_ in classes:
        class_path = os.path.join(data_path, class_)
        for img_path in os.listdir(class_path):
            if np.random.uniform()<=0.25:#rescale images
                image1 = os.path.join(class_path, img_path)
                image_select=random.choice(os.listdir(class_path))
                image2 = os.path.join(class_path, image_select)
                scale = np.random.uniform(0.3,0.6)#scaling factor
                select_index = random.choice([1,2])
                if select_index==1:
                    s1=int(scale*IMAGE_DIMS)#scale down
                    s2 = IMAGE_DIMS
                    scale_flag=1
                else:
                    s2=int(scale*IMAGE_DIMS)#scale down
                    s1 = IMAGE_DIMS
                    scale_flag=2
                pairs+=[[image1, image2, 1, s1, s2]]

                class_select = random.choice(classes)
                while class_select == class_:# keep trying if select the current class
                    class_select = random.choice(classes)
                class_path2 = os.path.join(data_path, class_select)
                image_select=random.choice(os.listdir(class_path2))
                image2 = os.path.join(class_path2, image_select)
                if scale_flag ==1:
                    s1 = IMAGE_DIMS
                    if np.random.uniform()<0.5:
                        s2=int(scale*IMAGE_DIMS)#scale down
                    else:
                        s2 = IMAGE_DIMS
                elif scale_flag ==2:
                    if np.random.uniform()<0.5:
                        select_index = random.choice([1,2])
                        if select_index==1:
                            s1=int(scale*IMAGE_DIMS)#scale down
                            s2 = IMAGE_DIMS
                        else:
                            s2=int(scale*IMAGE_DIMS)#scale down
                            s1 = IMAGE_DIMS
                scale_flag=0
                pairs+=[[image1, image2, 0, s1, s2]]

            image1 = os.path.join(class_path, img_path)
            image_select=random.choice(os.listdir(class_path))
            image2 = os.path.join(class_path, image_select)
            # image1=preprocess(image1)
            # image2=preprocess(image2)
            pairs+=[[image1, image2, 1, IMAGE_DIMS, IMAGE_DIMS]]


            class_select = random.choice(classes)
            while class_select == class_:# keep trying if select the current class
                class_select = random.choice(classes)
            class_path2 = os.path.join(data_path, class_select)
            image_select=random.choice(os.listdir(class_path2))
            image2 = os.path.join(class_path2, image_select)
            # image2=preprocess(image2)
            pairs+=[[image1, image2, 0, IMAGE_DIMS, IMAGE_DIMS]]

# %%
make_pairs()

# %%
pairs
# Out:
# [['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/68.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/0.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/68.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1112/14.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/13.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/29.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/13.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/827/24.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/7.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1118/58.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/859/44.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/18.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/35.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/18.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1446/0.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/32.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/28.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/32.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/549/0.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/59.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/49.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/59.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/279/69.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/59.png',
#   1,
#   62,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/267/31.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/53.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1485/34.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/47.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/32.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/47.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/250/26.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/32.png',
#   1,
#   112,
#   41],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1396/71.png',
#   0,
#   112,
#   41],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/68.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/439/57.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/67.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/4.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/67.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1148/50.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/70.png',
#   1,
#   112,
#   45],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/271/25.png',
#   0,
#   112,
#   45],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/35.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1936/13.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/13.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1667/49.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/32.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1031/1.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/32.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/579/69.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/64.png',
#   1,
#   112,
#   45],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/971/25.png',
#   0,
#   45,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/337/46.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   1,
#   112,
#   62],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1008/29.png',
#   0,
#   112,
#   62],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/44.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/341/29.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/57.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/43.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/57.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1207/45.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/57.png',
#   1,
#   49,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1277/39.png',
#   0,
#   112,
#   49],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/42.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/56.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/10.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1659/24.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/25.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/25.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1551/14.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/29.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/29.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/829/54.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/32.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/661/21.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/44.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/60.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/44.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1497/2.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/49.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/949/39.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/54.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1997/28.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/20.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/26.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/20.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1132/35.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/5.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/44.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/5.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1279/40.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/15.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/67.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/15.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/596/4.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/39.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/4.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/39.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1325/12.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/0.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/29.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/0.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1141/19.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/63.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/53.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/63.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/822/50.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/30.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/56.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/30.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1087/49.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/33.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/58.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/33.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1550/68.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/40.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/65.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/40.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/186/56.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/70.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/40.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/70.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/595/15.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/46.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/12.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/46.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/896/33.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/38.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/62.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/38.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/92/61.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/2.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/36.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/2.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/11/39.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/43.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/3.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/43.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1992/7.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/27.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/20.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/27.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1757/9.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/37.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/9.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/37.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/982/35.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/56.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/62.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/56.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1249/41.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/10.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/38.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/10.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/708/61.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/22.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/30.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/22.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1248/3.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/53.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/7.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/53.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1890/61.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/3.png',
#   1,
#   112,
#   52],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/5/51.png',
#   0,
#   52,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/20.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/12.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1834/47.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/49.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/6.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/49.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1620/9.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/7.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/42.png',
#   1,
#   112,
#   40],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/7.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/225/50.png',
#   0,
#   40,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/7.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/14.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/7.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1217/22.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/31.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/27.png',
#   1,
#   42,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/31.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/174/2.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/31.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/38.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/31.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/43/22.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/66.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/39.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/66.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/343/18.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/12.png',
#   1,
#   112,
#   51],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/710/43.png',
#   0,
#   112,
#   51],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/50.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/992/4.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/26.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/47.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/26.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1619/62.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/42.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/42.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1221/31.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/48.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/1.png',
#   1,
#   46,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/48.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/456/65.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/48.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/70.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/48.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/913/70.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/62.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/55.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/62.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/519/34.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/17.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/68.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/17.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1357/47.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/51.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/54.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/51.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1494/13.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/14.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/8.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/14.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/91/66.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/3.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/54.png',
#   1,
#   112,
#   48],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/3.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1245/50.png',
#   0,
#   48,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/3.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/3.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1797/44.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/58.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/18.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/58.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1020/6.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/34.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/13.png',
#   1,
#   112,
#   53],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/34.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/332/9.png',
#   0,
#   112,
#   53],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/34.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/33.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/34.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/297/34.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/60.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/21.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/60.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1352/13.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/54.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/4.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/54.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/812/56.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/11.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/26.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/11.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/677/11.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/36.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/48.png',
#   1,
#   112,
#   54],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/36.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/393/30.png',
#   0,
#   54,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/36.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/36.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/628/64.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/4.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/57.png',
#   1,
#   56,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/4.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/432/8.png',
#   0,
#   112,
#   56],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/4.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/6.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/4.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/167/32.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/9.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/16.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/9.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/273/16.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/65.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/30.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/65.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/702/20.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/6.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/60.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/6.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/771/47.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/16.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/45.png',
#   1,
#   112,
#   46],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/16.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/403/28.png',
#   0,
#   112,
#   46],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/16.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/56.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/16.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1836/4.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/55.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/40.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/55.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1816/38.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/68.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/64.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/68.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/338/43.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/13.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/18.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/13.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1196/13.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/54.png',
#   1,
#   112,
#   61],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1319/65.png',
#   0,
#   61,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/41.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1901/41.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/3.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1774/63.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/18.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/17.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/18.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1017/1.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/32.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/21.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/32.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/189/59.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/59.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/54.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/59.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/142/63.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/68.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/90/34.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/47.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/1.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/47.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1283/46.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/1.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1702/34.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/67.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/45.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/67.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1267/59.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/31.png',
#   1,
#   112,
#   60],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/493/50.png',
#   0,
#   112,
#   60],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/48.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1090/28.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/13.png',
#   1,
#   112,
#   61],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/74/55.png',
#   0,
#   112,
#   61],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/34.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1145/11.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/6.png',
#   1,
#   47,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1637/61.png',
#   0,
#   112,
#   47],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/8.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1103/44.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/69.png',
#   1,
#   112,
#   62],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/99/7.png',
#   0,
#   112,
#   62],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/47.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1771/24.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/40.png',
#   1,
#   54,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1547/70.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/49.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/833/34.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/28.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/953/65.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/57.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/50.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/57.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1017/14.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/19.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1168/11.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/71.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1210/35.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/25.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/22.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/25.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/129/35.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/29.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/57.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/29.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1512/30.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/51.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/576/23.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/44.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/2.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/44.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1290/17.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/70.png',
#   1,
#   112,
#   54],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1693/51.png',
#   0,
#   54,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/59.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1815/8.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/28.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/98/11.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/20.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1491/33.png',
#   1,
#   112,
#   112],
# ...
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/68.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/293/43.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/13.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/25.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/13.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1598/38.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/12.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/28.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1771/24.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/41.png',
#   1,
#   61,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1126/60.png',
#   0,
#   112,
#   61],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/45.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/23.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/731/59.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/18.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/36.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/18.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/243/13.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/32.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/35.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/32.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1834/35.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/59.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/57.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/59.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1790/41.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/32.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/61.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/643/11.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/47.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/3.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/47.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1937/24.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/67.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/50.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/41/69.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/67.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/61.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/67.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1160/67.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/57.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/52.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1015/44.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/48.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/1.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/432/55.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/60.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/24.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1832/13.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/29.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/41.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1744/69.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/19.png',
#   1,
#   36,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/741/22.png',
#   0,
#   112,
#   36],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/22.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/64.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/185/14.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/5.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/45.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1125/14.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/57.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/40.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/57.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1674/44.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/18.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/8.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/834/10.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/40.png',
#   1,
#   45,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1749/17.png',
#   0,
#   112,
#   45],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/46.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/69.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/329/33.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/25.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/63.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/25.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1430/68.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/29.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/59.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/29.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/326/28.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/22.png',
#   1,
#   112,
#   59],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/847/71.png',
#   0,
#   112,
#   59],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/31.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/19.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1370/40.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/44.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/70.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/44.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/756/43.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/41.png',
#   1,
#   112,
#   47],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/662/48.png',
#   0,
#   112,
#   47],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/15.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/35.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/502/50.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/56.png',
#   1,
#   37,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1023/37.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/30.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/71.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1326/32.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/20.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/32.png',
#   1,
#   65,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/20.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1597/63.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/20.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/12.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/20.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/364/41.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/5.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/51.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/5.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/292/19.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/15.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/48.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/15.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/564/60.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/39.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/44.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/39.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/231/31.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/0.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/26.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/0.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1804/5.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/63.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/29.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/63.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/874/49.png',
#   0,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/30.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/19.png',
#   1,
#   112,
#   58],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/30.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1754/25.png',
#   0,
#   112,
#   58],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/30.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/21.png',
#   1,
#   112,
#   112],
#  ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1342/30.png',
#   '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/348/31.png',
#   0,
#   112,
#   112],
#  ...]

# %%
print(len(pairs))
print(pairs[0])
# Out:
# 360910
# ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/68.png', '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1634/0.png', 1, 112, 112]

# %%
print(pairs[360909])
# Out:
# ['/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/256/55.png', '/home/halim/Documents/ECE 613 Image Processing/GitHub/Face_id_meta/data/1924/26.png', 0, 112, 112]

# %% [markdown]
# ### Pre-trained Model
#
# In this example are we going to fine-tune the [google/vit-base-patch16-224-in21k](https://huggingface.co/google/vit-base-patch16-224-in21k) a Vision Transformer (ViT) pre-trained on ImageNet-21k (14 million images, 21,843 classes) at resolution 224x224.
#
# You can easily adjust the `model_id` to another Vision Transformer model, e.g. `google/vit-base-patch32-384`

# %%
model_id = "google/vit-base-patch16-224-in21k"

# %% [markdown]
# ### Pre-processing
#
# To train our model we need to convert our "Images" to `pixel_values`. This is done by a [🤗 Transformers Feature Extractor](https://huggingface.co/docs/transformers/master/en/main_classes/feature_extractor#feature-extractor) which allows us to `augment` and convert the images into a 3D Array to be fed into our model.

# %%
from transformers import ViTFeatureExtractor
from tensorflow import keras 
from tensorflow.keras import layers


feature_extractor = ViTFeatureExtractor.from_pretrained(model_id)

# learn more about data augmentation here: https://www.tensorflow.org/tutorials/images/data_augmentation
data_augmentation = keras.Sequential(
    [
        layers.Resizing(feature_extractor.size, feature_extractor.size),
        layers.Rescaling(1./255),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# use keras image data augementation processing
def augmentation(examples):
    # print(examples["img"])
    examples["pixel_values"] = [data_augmentation(image) for image in examples["img"]]
    return examples


# basic processing (only resizing)
def process(examples):
    examples.update(feature_extractor(examples['img'], ))
    return examples
# Out:
# 2023-02-25 01:42:48.579796: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/halim/anaconda3/envs/ViT-setup/lib/python3.10/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
class L1Dist(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return tf.math.abs(embedding1-embedding2)


class L1Dist_mod(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return tf.math.reduce_sum(tf.math.abs(embedding1-embedding2), axis=1, keepdims=True)

class L2Dist(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        sum_square = tf.math.reduce_sum(tf.math.square(embedding1 - embedding2), axis=1, keepdims=True)
        return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))

class cosine(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return 1-tf.keras.losses.cosine_similarity(embedding1,embedding2)

class TF_L2Dist(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    def call(self, embedding1, embedding2):
        return tf.math.reduce_euclidean_norm(embedding1,embedding2)

# %% [markdown]
# ### Download the pretrained transformer model and fine-tune it.

# %%
# from transformers import TFViTForImageClassification, create_optimizer
# import tensorflow as tf

# # create optimizer wight weigh decay
# num_train_steps = len(tf_train_dataset) * num_train_epochs
# optimizer, lr_schedule = create_optimizer(
#     init_lr=learning_rate,
#     num_train_steps=num_train_steps,
#     weight_decay_rate=weight_decay_rate,
#     num_warmup_steps=num_warmup_steps,
# )

# # load pre-trained ViT model
# model = TFViTForImageClassification.from_pretrained(
#     model_id,
#     num_labels=len(img_class_labels),
#     id2label=id2label,
#     label2id=label2id,
# )

# # define loss
# loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # define metrics 
# metrics=[
#     tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
#     tf.keras.metrics.SparseTopKCategoricalAccuracy(3, name="top-3-accuracy"),
# ]

# # compile model
# model.compile(optimizer=optimizer,
#               loss=loss,
#               metrics=metrics
#               )

# %% [markdown]
# If you want to create you own classification head or if you want to add the augmentation/processing layer to your model, you can directly use the [functional Keras API](https://keras.io/guides/functional_api/). Below you find an example on how you would create a classification head.

# %%
# import tensorflow as tf
# from transformers import TFViTModel

# base_model = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
# Out:
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.

# %%
# base_model.summary()
# Out:
# Model: "tf_vi_t_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  86389248
#
# =================================================================
# Total params: 86,389,248
# Trainable params: 86,389,248
# Non-trainable params: 0
# _________________________________________________________________

# %%
# alternatively create Image Classification model using Keras Layer and ViTModel 
# here you can also add the processing layers of keras

import tensorflow as tf
from transformers import TFViTModel
from tensorflow.keras import regularizers

base_model = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
base_model.summary()

# inputs
pixel_values1 = tf.keras.layers.Input(shape=(3,IMAGE_DIMS,IMAGE_DIMS), name='pixel_values', dtype='float32')
pixel_values2 = tf.keras.layers.Input(shape=(3,IMAGE_DIMS,IMAGE_DIMS), name='pixel_values', dtype='float32')

# model layer
# vit = base_model.vit(pixel_values)[0]
vit1 = base_model.vit(pixel_values1)[0]
vit2 = base_model.vit(pixel_values2)[0]

# x1 = layers.Dense(1024, activation='sigmoid',kernel_regularizer=regularizers.l2(1e-3))(vit1)
# x2 = layers.Dense(1024, activation='sigmoid',kernel_regularizer=regularizers.l2(1e-3))(vit2)

siamese_layer=L1Dist_mod()
distances=siamese_layer(vit1, vit2)

# classifier = tf.keras.layers.Dense(1, activation='softmax', name='outputs')(distances)
classifier = tf.keras.layers.Dense(1, activation='sigmoid', name='outputs')(distances)

# model
keras_model = tf.keras.Model(inputs=(pixel_values1,pixel_values2) , outputs=classifier)
# Out:
# Downloading:   0%|          | 0.00/502 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/346M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.
